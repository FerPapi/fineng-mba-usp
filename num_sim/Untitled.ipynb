# %% [markdown]
# # Fernando Gomes Papi

# %%
import numpy as np
from tabulate import tabulate
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![image.png](attachment:1f56baac-fd50-4bde-9e00-b3b98be32b97.png)

# %% [markdown]
# ![image.png](attachment:7b89a4fa-4772-4663-8bf5-16ec1d87b773.png)

# %% [markdown]
# ![image.png](attachment:66c39cbf-bf91-41a2-a8a1-b5708cab0d1a.png)

# %% [markdown]
# ![image.png](attachment:ff327e4e-90e4-48a2-ab8b-e6681c9af2a6.png)
